# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder, StandardScaler

# %%
X_train2 = pd.read_csv("X_train.csv", index_col="Index")

# %%
sns.countplot(x="Gender", data=raw_data)
sns.displot(X_train2, x= "Gender", hue= "label", multiple="dodge", discrete=True, shrink=0.8)

# %%
sns.countplot(x="Age", data=raw_data)

# %%
sns.countplot(data = X_train2, x="Age", hue= "label", order= ["<18", "18-20", "21-25", "26-30", "31-35", ">36"])

# %%
ax = sns.countplot(x="Course", data=raw_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# Out:
# [Text(0, 0, 'Business'),
#  Text(0, 0, 'Social Sciences and Humanities'),
#  Text(0, 0, 'Art and Design'),
#  Text(0, 0, 'Science and engineering'),
#  Text(0, 0, 'Law/Legal studies'),
#  Text(0, 0, 'Media and Communications'),
#  Text(0, 0, 'Computing')]

# %%
bx = sns.displot(raw_data, x= "Course", hue= "label", multiple="dodge", discrete=True, shrink=0.8)
bx.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
sns.countplot(x="Academic", data=raw_data)

# %%
sns.countplot(data = X_train2, x="Academic", hue= "label", order= ['<40%', '40%~49%', '50%~59%', '60%~70%','>70%'])

# %%
sns.countplot(x="Attendance", data=X_train2, order = ['S4', 'S3','S2','S1', 'S0'])

# %%
sns.countplot(x="Attendance", data=X_train2, order = ['S4', 'S3','S2','S1', 'S0'], hue = "label")
